# %%
#1
class Customer:
  def __init__(self,name):
    self.name=name

  def greet(self,name=None):
    # print("")
    if name is None:
      print("Hello!")
    else:
      print("Hello David!")  
  def purchase(self,*args):
    print(self.name+", you purchased" + str(len(args))+"item(s):")
    for  i in args:
      print(i)


customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased3item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchased1item(s):
# orange juice

# %%
# #3
class Cat:
  def __init__(self,color="white",action="sitting"):
    self.color=color
    self.action=action
  def printCat(self):
        print(self.color +" cat is "+self.action)



  def changeColor(self,new_color):
    self.color=new_color

c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# white cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#2
class Panda:
    def __init__(self,name,gender,age):
        self.name=name
        self.gender=gender
        self.age=age
       
    def sleep(self,hour=None):
        if hour is None:
             return f"{self.name}'s duration is unknown thus should have only bamboo leaves"

        elif hour >= 3 and hour <= 5:
            return f"{self.name} sleeps {hour} hours daily and should have Mixed Veggies"

        elif hour >= 6 and hour <= 8:
            return f"{self.name} sleeps {hour} hours daily and should have Eggplant & Tofu"

        elif hour >= 9 and hour <= 11:
            return f"{self.name} sleeps {hour} hours daily and should have Broccoli Chicken"
        # if hour==None:
        #     return f"{self.name} duration is unknown thus should have only bamboo leaves"
        
        # elif 3<= hour<=5:
        #     return "{self.name} sleeps {hour} hours daily and should have Mixed Veggies"
        # # pass
        #self.hour=hour
        # if self.hour==10:
        #     x=((f"Ming Ming's duration is unknown thus should have only  bamboo leaves"))
        #     return x
        # else:
        #     x=(f"Pan Pan sleeps {self.hour} hours daily and should have Broccoli Chicken")
        #     x=(f"Kunfu sleeps {self.hour} hours daily and should have Mixed Veggies")  
        # return x
        
        
        
    
    # def sleep(self,hour=0):
    #     self.hour=hour
    #     print(f"Pan Pan sleeps {self.hour} hours daily and should have Broccoli Chicken")
    #     print(f"Kunfu sleeps {self.hour} hours daily and should have Mixed Veggies")
    #     print(f"Ming Ming's duration is unknown thus should have only  bamboo leaves")
        
        
        
    #     x=(f"Pan Pan sleeps {self.hour} hours daily and should have Broccoli Chicken")
    #     x=(f"Kunfu sleeps {self.hour} hours daily and should have Mixed Veggies")
    #     x=(f"Ming Ming's duration is unknown thus should have only  bamboo leaves")
    #      return x
    #     # pass

# Pan Pan sleeps 10 hours daily and should 
# have Broccoli Chicken 
# Kunfu sleeps 4 hours daily and should have 
# Mixed Veggies 
# Ming Ming's duration is unknown thus should 
# have only  bamboo leaves  
 


panda1 = Panda("Kunfu","Male", 5) 
panda2=Panda("Pan Pan","Female",3) 
panda3=Panda("Ming Ming","Female",8) 
 
print("{} is a {} Panda Bear who is {} year sold".format(panda1.name,panda1.gender,panda1.age)) 
 
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age)) 
 
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age)) 
print("===========================") 
print(panda2.sleep(10)) 
print(panda1.sleep(4)) 
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 year sold
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#4
class Student:
  def __init__(self,name="default student"):
    self.name=name
    # pass
    
    # if name=="default":
    #   # print("Hello default student")
    # else:
    #   # print("Hello",self.name)
  def quizcalc(self,*args):

    total=0
    for i in args:
      total+=i
      self.avg=total/3

      # self.x=/2
   
  def printdetail(self):
    print(f"Hello {self.name}")
    print(f"Your averagge quiz score is {self.avg}")


s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your averagge quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your averagge quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your averagge quiz score is 9.666666666666666

# %%
#5
class Student:
  def __init__(self,name,id,dep="CSE"):
    self.name=name
    self.id=id
    self.dep=dep



  def dailyEffort(self,hour):
    self.hour= hour
    if hour <= 2: 
     self.x='Suggestion: Should give more effort!'
    elif hour <= 4:
     self.x='Suggestion: Keep up the good work!'
    else:
     self.x='Suggestion: Excellent! Now motivate others.'

  def printDetails(self):
    print(f"""Name: {self.name}
ID: {self.id}
Department: {self.dep}
Daily Effort: {self.hour} hour(s)
{self.x}""")
    





harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
#6
class Patient:
    def __init__(self,name,age):
        self.name=name
        self.age  = age
        
    def add_Symptom(self,*args):
        self.y=""
        for i in args:
            self.y+=" "+i+","
      
        
       
        # print(y[0:len(y)-1])
            
        # if len(args)==1:
        #     self.x= f"Name:{self.name}\nAge:{self.age}\nSymptoms: {args}"
        # elif len(args)==2:
        #     self.x= f"Name:{self.name}\nAge:{self.age}\nSymptoms: {args}"
        # else:
        #     self.x= f"Name:{self.name}\nAge:{self.age}\nSymptoms: {args}"

    def printPatientDetail(self):
        print("Name:",self.name)
        print("Age:",self.age)
        print("Symptoms:",self.y[1:-1])
        

p1 = Patient("Thomas", 23) 
p1.add_Symptom("Headache") 
p2 = Patient("Carol", 20) 
p2.add_Symptom("Vomiting", "Coughing") 
p3 = Patient("Mike", 25) 
p3.add_Symptom("Fever", "Headache", "Coughing") 
print("=========================") 
p1.printPatientDetail() 
print("=========================") 
p2.printPatientDetail() 
print("=========================") 
p3.printPatientDetail()
# Out:
# ...
# Name: Thomas
# Age: 23
# Symptoms: Headache
# ...
# Name: Carol
# Age: 20
# Symptoms: Vomiting, Coughing
# ...
# Name: Mike
# Age: 25
# Symptoms: Fever, Headache, Coughing

# %%
string_a = "Hello"
string_b = "Cena"

# Index based:
print("{0}, John {1}"
      .format(string_a, string_b))
print(string_a)
# Object based:
print("{greeting}, John {last_name}"
      .format(greeting=string_a, last_name=string_b))
# Out:
# Hello, John Cena
# Hello
# Hello, John Cena

# %%
#7



class Match:
    def __init__ (self,name):
        print("5..4..3..2..1.. Play !!! ")
        
        a=name.split("-")
        self.name=a
        self.run=0 #! ekane 0 dwa lagbe karon taholei kaj kroe karon ekane first0 dore then add kra hosse
        # self.over=0
        self.wicket=0

    def add_run(self,run):
        # self.run+=0 #! ekane dile hobena karon prottekbar ei 0 dore + korbe
        self.run+=run

    def add_over(self,over):
        self.over=0
        if self.over==5:
            print("Warning! Cannot add 5 over/s (5 over match)")
            
        else:
            self.over+=over
            
  
    def add_wicket(self,wicket):
        self.wicket+=wicket
        
      
    def print_scoreboard(self):
        x=f"""Batting Team: {self.name[0]}
Bowling Team: {self.name[1]}
Total Runs: {self.run} Wickets: {self.wicket} Overs: {self.over}"""
        return x
 
  
match1 = Match("Rangpur Riders-Cumilla Victorians") 
print("=========================") 
match1.add_run(4) 
match1.add_run(6) 
match1.add_over(1) 
print(match1.print_scoreboard()) 
print("=========================") 
match1.add_over(5) 
print("=========================") 
match1.add_wicket(1) 
print(match1.print_scoreboard())
# Out:
# 5..4..3..2..1.. Play !!!
# ...
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 0 Overs: 1
# ...
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 1 Overs: 5

# %%
#8
class ParcelKoro:
    
    
    def __init__ (self,name="No name set",weight=None):
        self.name=name
        self.total_fee=0
        if weight==None:
            self.total_fee==0
        elif weight==0:
            self.total_fee==0
        else:
            self.total_fee=(weight*20)+self.location_charge
        # return self.total_fee   
        
    def calculateFee(self,place=None):
        self.location_charge=0
        if place==None:
            self.location_charge==50
                
        else:
            self.location_charge==100        
        
     

    def printDetails(self):
        print(self.total_fee)
        

print("**********************") 
p1 = ParcelKoro() 
p1.calculateFee() 
p1.printDetails() 
print("**********************") 
p2 = ParcelKoro('Bob The Builder') 
p2.calculateFee() 
p2.printDetails() 
print("----------------------------") 
p2.product_weight = 15 
p2.calculateFee() 
p2.printDetails() 
print("**********************") 
p3 = ParcelKoro('Dora The Explorer', 10) 
p3.calculateFee('Dhanmondi') 
p3.printDetails()
# Out:
# **********************
# 0
# **********************
# 0
# ----------------------------
# 0
# **********************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Shihab\02CSE\CSE111\W4 Method and Constractor overloading\BuxClassI Notes I Practice I L\lab4.ipynb Cell 9' in <cell line: 43>()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000008?line=40'>41</a> p2.printDetails()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000008?line=41'>42</a> print("**********************")
# ...

# %%
#8
class ParcelKoro:
    
    
    def __init__ (self,name=None,weight=None):
        self.name=name

        self.weight=weight
        if self.weight==None:
            self.weight=0
    def calculateFee(self,place=None):
        self.place=place
        if self.place==None:
           location_charge=50
        else:
            location_charge=100
        if self.weight==None:
            self.total_fee=0
        else:           
           self.total_fee=(self.weight * 20)+location_charge    
    def printDetails(self):
        if self.name==None:
            self.name=="No Name set"
        print(f"""Customer name: {self.name}
Product Weight: {self.weight}
Total fee: {self.total_fee}            
            """)   
print("**********************") 
p1 = ParcelKoro() 
p1.calculateFee() 
p1.printDetails() 
print("**********************") 
p2 = ParcelKoro('Bob The Builder') 
p2.calculateFee() 
p2.printDetails() 
print("----------------------------") 
p2.product_weight = 15 
p2.calculateFee() 
p2.printDetails() 
print("**********************") 
p3 = ParcelKoro('Dora The Explorer', 10) 
p3.calculateFee('Dhanmondi') 
p3.printDetails()
# Out:
# **********************
# Customer name: None
# Product Weight: 0
# Total fee: 50
#
# **********************
# Customer name: Bob The Builder
# Product Weight: 0
# Total fee: 50
#
# ----------------------------
# Customer name: Bob The Builder
# Product Weight: 0
# Total fee: 50
#
# **********************
# Customer name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#8 #! git #f
# Problem - 12


class ParcelKoro:
    def __init__(self, name=None, product_weight=None):
        self.name = name
        self.product_weight = product_weight
        if self.product_weight == None:
            self.product_weight = 0

    def calculateFee(self, location=None):
        self.location = location

        if location == None:
            location_charge = 50
        else:
            location_charge = 100

        if self.product_weight == 0:
            self.total_fee = 0
        else:
            self.total_fee = (self.product_weight * 20) + location_charge

    def printDetails(self):
        if self.name == None:
            self.name = "No name set"

        print(f"Customer Name: {self.name}")
        print(f"Product Weight: {self.product_weight}")
        print(f"Total fee: {self.total_fee}")


print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro("Bob The Builder")
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro("Dora The Explorer", 10)
p3.calculateFee("Dhanmondi")
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#9
#! not working with none idk
class Batsman:
    def __init__ (self,run,ball):
        # self.name="New Batsman"
        self.run=run
        self.ball=ball
        self.name="New Batsman"
        # if self.name==None:
        #      return "New Batsman"
    def setName(self,name):
        self.name=name
        # pass    
    def printCareerStatistics(self):
        pass
 
 
 

b1 = Batsman(6101, 7380) 
b1.printCareerStatistics() 
print("============================") 
b2 = Batsman("Liton Das", 678, 773) 
b2.printCareerStatistics() 
print("----------------------------") 
print(b2.battingStrikeRate()) 
print("============================") 
b1.setName("Shakib Al Hasan") 
b1.printCareerStatistics() 
print("----------------------------") 
print(b1.battingStrikeRate())
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Shihab\02CSE\CSE111\W4 Method and Constractor overloading\BuxClassI Notes I Practice I L\lab4.ipynb Cell 1' in <cell line: 23>()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000000?line=20'>21</a> b1.printCareerStatistics()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000000?line=21'>22</a> print("============================")
# ---> <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000000?line=22'>23</a> b2 = Batsman("Liton Das", 678, 773)
# ...

# %%
#9 #! final
class Batsman:
    def __init__(self, *args):
        if len(args) == 2:
            runs, balls = args
        else:
            player, runs, balls = args

        if len(args) != 2:
            self.name = player
        else:
            self.name = "New Batsman"

        self.runs = runs
        self.balls = balls

    def setName(self, name):
        self.name = name

    def battingStrikeRate(self):
        return (self.runs) / (self.balls) * 100

    def printCareerStatistics(self):
        print(f"Name: {self.name}")
        print(f"Runs Scored: {self.runs}, Balls Faced: {self.balls}")


b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101, Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678, Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101, Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#9 #!git me \\
class Batsman:
    def __init__(self,*args):
        if len(args)==2:
            run,ball=args
        else:
            name,run,ball=args
        
        if len(args)!=2:
            self.name=name
        else:
            self.name="New Batsman"   
        self.run=run
        self.ball=ball        
                
    def setName(self,name):
        self.name=name
    def battingStrikeRate():
       return (self.run) / (self.ball) * 100
        
    def printCareerStatistics(self):
        print(f"Name: {self.name}")
        print(f"Runs Scored: {self.run}, Balls Faced: {self.ball}")

         

b1 = Batsman(6101, 7380) 
b1.printCareerStatistics() 
print("============================") 
b2 = Batsman("Liton Das", 678, 773) 
b2.printCareerStatistics() 
print("----------------------------") 
print(b2.battingStrikeRate()) 
print("============================") 
b1.setName("Shakib Al Hasan") 
b1.printCareerStatistics() 
print("----------------------------") 
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101, Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678, Balls Faced: 773
# ----------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Shihab\02CSE\CSE111\W4 Method and Constractor overloading\BuxClassI Notes I Practice I L\lab4.ipynb Cell 13' in <cell line: 33>()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000016?line=30'>31</a> b2.printCareerStatistics()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000016?line=31'>32</a> print("----------------------------")
# ...

# %%
#10
class EPL_Team:
  def __init__(self,club,song="No Slogan",title=0):
    self.club=club
    self.song=song
    self.title=0
    
  def showClubInfo(self):
    return (f"""Name: {self.club}
Song:{self.song}
Total No of title:{self.title}""")
    # pass

  def increaseTitle(self):
    self.title+=1

  def changeSong(self,new_s):
    self.song=new_s
    





manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song:Glory Glory Man United
# Total No of title:0
# ##################
# Name: Manchester United
# Song:Glory Glory Man United
# Total No of title:1
# ...
# Name: Chelsea
# Song:No Slogan
# Total No of title:0
# Name: Chelsea
# Song:Keep the blue flag flying high
# Total No of title:0

# %%
#11 #araf
class Author:
  def __init__(self,*items):

    if len(items)>0:
      self.name=items[0]
      self.books=list(items[1:])

    else:
      self.name="Default"
      self.books=list() 
  def addBooks(self,*holy):
    self.books.extend(holy)

  def changeName(self,name):
    self.name=name

  def printDetails(self):
    print(f"""Author nmae: {self.name}
-------         
List of Books!""")
    for i in self.books:
      print(i)

auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author nmae: Humayun Ahmed
# -------
# List of Books!
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author nmae: Mario Puzo
# -------
# List of Books!
# The Godfather
# Omerta
# The Sicilian
# ...
# Author nmae: Paolo Coelho
# -------
# List of Books!
# The Alchemist
# The Fifth Mountain

# %%
#11 #! me




class Author:
    def __init__(self,name):
    
     
            
    def addBooks(self):
        Pass

    def changeName(self):
        
        pass
    
    def printDetails():
    pass



auth1 = Author('Humayun Ahmed') 
auth1.addBooks('Deyal', 'Megher Opor Bari') 
auth1.printDetails() 
print('===================') 
auth2 = Author() 
print(auth2.name) 
auth2.changeName('Mario Puzo') 
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian') 
print('===================') 
auth2.printDetails() 
print('===================') 
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain') 
auth3.printDetails()

# %%
#12
class 








taxi1 = TaxiLagbe('1010-01', 'Dhaka') 
print('-------------------------------') 
taxi1.addPassenger('Walker_100', 'Wood_200') 
taxi1.addPassenger('Matt_100') 
taxi1.addPassenger('Wilson_105') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi1.addPassenger('Karen_200') 
print('-------------------------------') 
taxi1.printDetails() 
print('-------------------------------') 
taxi2 = TaxiLagbe('1010-02', 'Khulna') 
taxi2.addPassenger('Ronald_115') 
taxi2.addPassenger('Parker_215') 
print('-------------------------------') 
taxi2.printDetails()

# %%
#13
class Account:
  def __init__ (self,name="Default Account",balance=0.0):
    self.name=name
    self.balance=balance

  def details(self):
    return(f"""{self.name}
{self.balance}""")
  def withdraw(self,ammount):
    new_balance=self.balance-ammount
    if new_balance<3071:
      print("Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.")
    else:
      print("Withdraw successful! New balance is:")
      print(new_balance)
   
a1=Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
333
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is:
# 3071.0

# %%
#13 #! again practice
class Account:
    # def __init__(self,name=None,balance=0.0):#! evabe ekta none ase output a
    def __init__(self,name="Default Account",balance=0.0):
        self.name=name
        self.balance=balance
        # if self.name==None:
        #     print("Default Account")
        # else:
        #     return self.name==name
        # else:
        #     # print(self.name)
        #     self.name=name
        
        # if self.ammount==
        
    def details(self):
        return f"""{self.name}
{self.balance}"""
        # x=self.name 
        # y=self.balance
        # return x,y
        # self.name 
        # self.balance
    
                
        # print(self.name)
        # print(self.balance)
        # pass
    # def name():
    #     pass
    # def balance():
    #     pass
    def withdraw(self,ammount):
        self.ammount=ammount
        new_balance=self.balance-self.ammount
        if new_balance<3071:
         print("Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.")
        else:
         print("Withdraw successful! New balance is:")
         print(new_balance)
        
    
    
    
a1 = Account() 
print(a1.details()) 
print("------------------------") 
a1.name = "Oliver" 
a1.balance = 10000.0 
print(a1.details()) 
print("------------------------") 
a2 = Account("Liam") 
print(a2.details()) 
print("------------------------") 
a3 = Account("Noah",400) 
print(a3.details()) 
print("------------------------") 
a1.withdraw(6930) 
print("------------------------") 
a2.withdraw(600) 
print("------------------------") 
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is:
# 3071.0

# %%
# Task 17 
class Test5: 
    def __init__(self): 
      self.sum = 0 
      self.y = 0 
    def methodA(self):    
      x=y=k=0 
      msg = [5]   
      while (k < 2): 
        y += msg[0]      
        x = y + self.methodB(msg, k) 
        self.sum = x + y + msg[0] 
        print(x ," " , y, " " , self.sum) 
        k+=1  
    def methodB(self, mg2, mg1): 
            x = 0 
            self.y += mg2[0] 
            x = x + 3 + mg1 
            self.sum += x + self.y 
            mg2[0] = self.y + mg1 
            mg1 += x + 2 
            print(x , " " ,self.y, " " , self.sum) 
            return mg1
        
t1 = Test5() 
t1.methodA() 
t1.methodA() #
t1.methodA()
# Out:
# 3   5   8
# 10   5   20
# 4   10   34
# 17   10   38
# 3   15   56
# 10   5   30
# 4   30   64
# 27   20   78
# 3   35   116
# 10   5   50
# 4   70   124
# 47   40   158

# %%
#15
class FinalT6A: 
    def __init__(self, x, p): 
        self.temp, self.sum, self.y = 4, 0, 1 
        self.temp += 1 
        self.y = self.temp - p 
        self.sum = self.temp + x 
        print(x, self.y, self.sum) 
    def methodA(self): 
        x = 0 
        y = 0 
        y = y + self.y 
        x = self.y + 2 + self.temp 
        self.sum = x + y + self.methodB(self.temp, y) 
        print(x, y, self.sum) 
    def methodB(self, temp, n): 
        x = 0 
        temp += 1 
        self.y = self.y + temp 
        x = x + 3 + n 
        self.sum = self.sum + x + self.y 
        print(x, self.y, self.sum) 
        return self.sum
q1 = FinalT6A(2,1) 
q1.methodA() 
q1.methodA()
# Out:
# 2 4 7
# 7 10 24
# 11 4 39
# 13 16 68
# 17 10 95

# %%
#16
class Quiz3A: 
    def __init__(self, k = None): 
        self.temp, self.sum, self.y = 4, 0, 0 
        if k != None: 
            self.temp += 1 
            self.temp = self.temp 
            self.sum = self.temp + k 
            self.y = self.sum - 1 
        else: 
              self.y = self.temp - 1 
              self.sum = self.temp + 1 
              self.temp += 2     
    def methodB(self, m, n): 
        x = 0 
        self.temp += 1 
        self.y = self.y + m + (self.temp) 
        x = x + 2 + n 
        self.sum = self.sum + x + self.y 
        print(x, self.y, self.sum) 
        return self.sum
a1 = Quiz3A() 
a1.methodB(1,2) 
a2 = Quiz3A(3) 
a2.methodB(2,4) 
a1.methodB(2,1) 
a2.methodB(1,3)
# Out:
# 4 11 20
# 6 15 29
# 3 21 44
# 5 23 57
# 57

# %%
#18
class Test4: 
    def __init__(self): 
        self.sum, self.y = 0, 0 
    def methodA(self): 
        x, y = 0, 0 
        msg = [0] 
        msg[0] = 5 
        y = y + self.methodB(msg[0]) 
        x = y + self.methodB(msg, msg[0]) 
        self.sum = x + y + msg[0] 
        print(x, y, self.sum) 
    def methodB(self, *args): 
        if len(args) == 1: 
            mg1 = args[0] 
            x, y = 0, 0 
            y = y + mg1 
            x = x + 33 + mg1 
            self.sum = self.sum + x + y 
            self.y = mg1 + x + 2 
            print(x, y, self.sum) 
            return y 
        else: 
            mg2, mg1 = args 
            x = 0 
            self.y = self.y + mg2[0] 
            x = x + 33 + mg1 
            self.sum = self.sum + x + self.y 
            mg2[0] = self.y + mg1 
            mg1 = mg1 + x + 2 
            print(x, self.y, self.sum) 
            return self.sum 
 
t3 = Test4() 
t3.methodA() 
t3.methodA() 
t3.methodA() 
t3.methodA()
# Out:
# 38 5 43
# 38 50 131
# 136 5 196
# 38 5 239
# 38 50 327
# 332 5 392
# 38 5 435
# 38 50 523
# 528 5 588
# 38 5 631
# 38 50 719
# 724 5 784

# %%
#19
class msgClass: 
    def __init__(self): 
        self.content = 0  
class Q5: 
    def __init__(self): 
        self.sum = 1 
        self.x = 2 
        self.y = 3  
    def methodA(self): 
          x, y = 1, 1 
          msg = [] 
          myMsg = msgClass() 
          myMsg.content = self.x 
          msg.append(myMsg)   
          msg[0].content = self.y + myMsg.content 
          self.y = self.y + self.methodB(msg[0]) 
          y = self.methodB(msg[0]) + self.y 
          x = y + self.methodB(msg[0], msg) 
          self.sum = x + y + msg[0].content 
          print(x," ", y," ", self.sum)     
    def methodB(self, mg1, mg2 = None): 
        if mg2 == None: 
            x, y = 5, 6 
            y = self.sum + mg1.content 
            self.y = y + mg1.content 
            x = self.x + 7 +mg1.content 
            self.sum = self.sum + x + y 
            self.x = mg1.content + x +8 
            print(x, " ", y," ", self.sum) 
            return y 
        else: 
            x = 1 
            self.y += mg2[0].content 
            mg2[0].content = self.y + mg1.content 
            x = x + 4 + mg1.content 
            self.sum += x + self.y 
            mg1.content = self.sum - mg2[0].content 
            print(self.x, " ",self.y," ", self.sum) 
            return self.sum 
 
 
 
q = Q5() 
q.methodA()
# Out:
# 14   6   21
# 39   26   86
# 52   36   168
# 225   57   409

# %% [markdown]
# ######################### QUIZZZ 2 ################
#
#
#
#
#
#
#
#
#
#
#
# qqqqqqqqqqqq

# %%
# quiz question {set A}
class Order:
    def __init__(self,name,place,times = None):
        self.name = name
        self.place = place
        self.times = times
        self.items  = []
        if times is not None:
            print(f'{self.name} ordered {self.times} times from {self.place}')
        else:
            print(f'{self.name} ordered from {self.place}')

    def addCart(self,*items):
        for i in items:
            if i == 'Lamb Burger':
                print('Sorry, only Chicken Burger and Beef Burger are available.')
            else:
                self.items.append(i)
                print(i,'added to the cart')
        
    def printDetails(self,search = None):
        if search is None:
            print(f'{self.name} order details:')
            for i in self.items:
                print(i)
        else:
            print(f'{self.name} order details:')
            for i in self.items:
                lst = i.split(' ')
                if lst[1] == search:
                    print(i)
p1 = Order('Tom','Dhanmondi',16)
print('1--------------------')
p1.addCart('Chicken Burger','Beef Burger','Naga Drums')
print('2--------------------')
p1.addCart('Oreo Shake')
print('3--------------------')
p1.printDetails()
print('4--------------------')
p1.printDetails('Burger')
print('5--------------------')
p2 = Order('Jon','Mohakhali')
print('6--------------------')
p2.addCart('French Fries','Lamb Burger')
# Out:
# Tom ordered 16 times from Dhanmondi
# 1--------------------
# Chicken Burger added to the cart
# Beef Burger added to the cart
# Naga Drums added to the cart
# 2--------------------
# Oreo Shake added to the cart
# 3--------------------
# Tom order details:
# Chicken Burger
# Beef Burger
# Naga Drums
# Oreo Shake
# 4--------------------
# Tom order details:
# Chicken Burger
# Beef Burger
# 5--------------------
# Jon ordered from Mohakhali
# 6--------------------
# French Fries added to the cart
# Sorry, only Chicken Burger and Beef Burger are available.

# %%
"""Quiz-2 {Set B} question solve"""

#write your code here
class Group:
    
    def __init__(self, *details):
        self.lst = []
        
        if len(details) > 1:
            self.name = details[0]
            self.num = details[1]
            print(f"A new group {self.name} with {self.num} members has been created")
        else:
            self.name = details[0]
            print(f"A new group {self.name} has been created")
        
        
    def addMember(self, *iDs):
        for iD in iDs:
            (self.lst).append(iD)
            if int(iD[0:2]) >= 20:
                print(f"{iD} added to the list")
            else:
                print("Sorry, only students enrolled from year 2020 onwards are allowed")
            
            
    def printDetails(self, year=None):
        print(f"{self.name}'s member details:")
        if year == None:
            for elm in self.lst:
                print(elm)
        else:
            for i in range(len(self.lst)):
                if ((self.lst[i])[0:2]) == year:
                    print(self.lst[i])
    

#Do not change the following lines of code.
g1 = Group("Eclipse",5)
print("1-------------------------")
g1.addMember("20121043","21101602","22101563")
print("2-------------------------")
g1.addMember("20141623")
print("3-------------------------")
g1.printDetails()
print("4-------------------------")
g1.printDetails("20")
print("5-------------------------")
g2=Group("Estoile")
print("6-------------------------")
g2.addMember("21202458","18131201")
# Out:
# A new group Eclipse with 5 members has been created
# 1-------------------------
# 20121043 added to the list
# 21101602 added to the list
# 22101563 added to the list
# 2-------------------------
# 20141623 added to the list
# 3-------------------------
# Eclipse's member details:
# 20121043
# 21101602
# 22101563
# 20141623
# 4-------------------------
# Eclipse's member details:
# 20121043
# 20141623
# 5-------------------------
# A new group Estoile has been created
# 6-------------------------
# 21202458 added to the list
# Sorry, only students enrolled from year 2020 onwards are allowed

# %% [markdown]
# ###################                             UNGRADED                   ###########################

# %%
#20 #! 1st try

#https://www.torrentbd.net/forums.php?action=viewpost&postid=347498 #! Solution froom chegg 
class Student:
    # def __init__(self,name=None,*args):

        # self.name=name
        # if self.name==None:
        #     self.name="Bob"
        # else:
        #     self.name=self.name
        # self.dep=*args[1]    
    def __init__(self,*args):
        if len *args==0:
            self.name=="Bob"
            self.dep=="CSE"
        elif len *args==1:
            self.name=args[0]
            self.dep=self.dep    
        else:
            self.name=args[0]
            self.dep=self.dep
                
            
           
    def update_name(self,name):
        self.name=name
    
    
    def Update_depertment(self,dep):
        self.dep=dep
        
    def enroll(self,enroll_):
        self.enroll_=enroll_  

s1 = Student() 
print("=========================") 
s2 = Student("Carol") 
print("=========================") 
s3 = Student("Jon", "EEE") 
print("=========================") 
s1.update_name("Bob") 
s1.update_department("CSE") 
s2.update_department("BBA") 
s1.enroll("CSE110", "MAT110", "ENG091") 
s2.enroll("BUS101") 
s3.enroll("MAT110", "PHY111") 
print("###########################") 
s1.printDetail() 
print("=========================") 
s2.printDetail() 
print("=========================") 
s3.printDetail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Shihab\02CSE\CSE111\W4 Method and Constractor overloading\BuxClassI Notes I Practice I L\lab4.ipynb Cell 27 in <cell line: 34>()
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000026?line=30'>31</a>     def enroll(self,enroll_):
#      <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000026?line=31'>32</a>         self.enroll_=enroll_
# ---> <a href='vscode-notebook-cell:/d%3A/Shihab/02CSE/CSE111/W4%20Method%20and%20Constractor%20overloading/BuxClassI%20Notes%20I%20Practice%20I%20L/lab4.ipynb#ch0000026?line=33'>34</a> s1 = Student()
# ...

# %%
#20 #! from chegg
class Student: #Student class
    def __init__(self, name='', dept=''):
        self.name=name #initialize name variable
        self.dept=dept #initialize dept variable
        if(len(name)>0 and len(dept)>0): #check name and dept has value or not
         print(name+" is from "+dept+" department") #print the message
        elif(len(name)>0): #check name has value or not
         print("Department for "+name+" needs to be set") #print the message
        else:
         print("Student name and department need to be set") #print the message
    def update_name(self,name): #update_name method definition
     self.name=name #assign parameter name to self.name
    def update_department(self,dept): #update_department method definition
     self.dept=dept #assign parameter dept to self.dept
    def enroll(self,*argv): #enroll method definition
      self.course=[] #initialize empty list
      for arg in argv: #iterate values from argv
       self.course.append(arg) #add arg to course list
    def printDetail(self):
        print("Name: "+self.name) #print name
        print("Department: "+self.dept) #print dept
        print(self.name+" enrolled in "+str(len(self.course))+" course(s):")
        print(', '.join(self.course)) #print course details #! join method ta list e kaj kore look down for example

s1 = Student() #create Student object
print("=========================")
s2 = Student("Carol") #create Student object
print("=========================")
s3 = Student("Jon", "EEE") #create Student object
print("=========================")
s1.update_name("Bob") #call the update_name method
s1.update_department("CSE") #call the update_department method
s2.update_department("BBA") #call the update_department method
s1.enroll("CSE110", "MAT110", "ENG091") #call the enroll method
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail() #call the printDetail method
print("=========================")
s2.printDetail() #call the printDetail method
print("=========================")
s3.printDetail() #call the printDetail method
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s):
# CSE110, MAT110, ENG091
# ...
# Name: Carol
# Department: BBA
# Carol enrolled in 1 course(s):
# BUS101
# ...
# Name: Jon
# Department: EEE
# Jon enrolled in 2 course(s):
# MAT110, PHY111

# %%
sentence=["this","is","a","sentence"]
"-".join(sentence)

    # print(sentence)
# Out:
# 'this-is-a-sentence'

# %%
#20 #!again //


class Student:
    
    def __init__(self,name="",dep=""):
        self.name=name
        self.dep=dep
        if len(name)>0 and len(dep)>0:
            print(name,"is from",dep,"depertment")
        elif len(name)>0:
            print("Depertment for",name,"needs to be set")
        else:
            print("Student name and department need to be set")    
        

            
           
    def update_name(self,name):
        self.name=name
    
    
    def update_department(self,dep):
        self.dep=dep
        
    def enroll(self,*args):
        self.course=[]
        for i in args:
              self.course.append(i)
        # ",".join(self.course)
        
    def printDetail(self):
        print("Name :",self.name)
        print("Depertment :",self.dep)
        print(self.name,"enrolled in ",len(self.course),"course(s)")
        print(",".join(self.course)) #!
s1 = Student() 
print("=========================") 
s2 = Student("Carol") 
print("=========================") 
s3 = Student("Jon", "EEE") 
print("=========================") 
s1.update_name("Bob") 
s1.update_department("CSE") 
s2.update_department("BBA") 
s1.enroll("CSE110", "MAT110", "ENG091") 
s2.enroll("BUS101") 
s3.enroll("MAT110", "PHY111") 
print("###########################") 
s1.printDetail() 
print("=========================") 
s2.printDetail() 
print("=========================") 
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Depertment for Carol needs to be set
# ...
# Jon is from EEE depertment
# ...
# ###########################
# Name : Bob
# Depertment : CSE
# Bob enrolled in  3 course(s)
# CSE110,MAT110,ENG091
# ...
# Name : Carol
# Depertment : BBA
# Carol enrolled in  1 course(s)
# BUS101
# ...
# Name : Jon
# Depertment : EEE
# Jon enrolled in  2 course(s)
# MAT110,PHY111

# %%
#21 #! //
class Student:
    def __init__(self,*args):
        self.name=args[0]
        self.id=args[1]
        self.dep=args[2]

    def details(self):
        return(f"""Name : {self.name}
ID: {self.id}
Depertment:{self.dep}""")

    def advise(self,*course):
        self.course=[]
        for i in course:
         self.course.append(i)
        if 3<=len(self.course)<=4:
            print(self.name,"you have taken",len(self.course)*3,"credits.")
            print("List of Courses:",",".join(self.course))
            print("Status : Ok")
        elif len(self.course)<3:
            print(self.name,"you have taken",len(self.course)*3,"credits.")
            print("List of Courses:",",".join(self.course))
            print("Status: You have to take at least",3-len(self.course),"more course")
            
        else:
            print(self.name,"you have taken",len(self.course)*3,"credits.")
            print("List of Courses:",",".join(self.course))
            print(f"Status: You have to drop at least",len(self.course)-4,"course.")
            

s1 = Student("Alice", "20103012", "CSE")
s2 = Student("Bob", "18301254", "EEE")
s3 = Student("Carol", "17101238", "CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102",
          "CSE111", "CSE230")
# Out:
# ##########################
# Name : Alice
# ID: 20103012
# Depertment:CSE
# ##########################
# Name : Bob
# ID: 18301254
# Depertment:EEE
# ##########################
# Alice you have taken 9 credits.
# List of Courses: CSE110,MAT110,PHY111
# Status : Ok
# ##########################
# Bob you have taken 6 credits.
# List of Courses: BUS101,MAT120
# Status: You have to take at least 1 more course
# ##########################
# Carol you have taken 15 credits.
# List of Courses: MAT110,PHY111,ENG102,CSE111,CSE230
# Status: You have to drop at least 1 course.

# %%
#21 by araf
class Student:
    def __init__(self, name, id, dep):
        self.name = name
        self.id = id
        self.dep = dep

    def details(self):
        return f"""Name: {self.name}
ID: {self.id}
Department: {self.dep}"""

    def advise(self, *courses):
        self.courses = courses
        credit = len(self.courses)*3.0
        print(f"""{self.name}, you have taken {credit} credits.
List of courses: {", ".join(self.courses)}""")
        if len(courses) < 3:
            print(
                f"Status: You have to take at least {3-len(courses)} more course.")
        elif 3 <= len(courses) <= 4:
            print("Status: Ok")
        else:
            print(
                f"Status: You have to drop at least {len(courses)-4} course.")


# Do not change the following lines of code.
s1 = Student("Alice", "20103012", "CSE")
s2 = Student("Bob", "18301254", "EEE")
s3 = Student("Carol", "17101238", "CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102",
          "CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses: CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Bob, you have taken 6.0 credits.
# List of courses: BUS101, MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol, you have taken 15.0 credits.
# List of courses: MAT110, PHY111, ENG102, CSE111, CSE230
# Status: You have to drop at least 1 course.

# %%
#22 #! not working
class Hotel:
    def __init__(self,hotel):
        self.hotel=hotel
        print("Staff with ID 1 is added")
        # pass
    def addStuff (self,name,age,num=None):
        self.name=name
        self.age=age
        self.num=num
        if self.num==None:
            self.num="000"
        else:
            self.num=num    
        
    def getStuffById(self,x):
        self.x=x
        return f"""Staff ID: {self.x}
Name: {self.name}
Age: {self.age}
Phone no.: {self.num}"""
    def addGuest(self,name,age,num):
        self.name=name
        self.age=age
        self.num=num
        print("Guestt with id",self.x,"is created")
    def getGuestById(self,y):
        # print("Guestt with id",self.x,"is created")
        
        self.y=y
        return f"""Guest ID: {self.y}
Name: {self.name}
Age: {self.age}
Phone no.: {self.num}"""
        
    def allStaffs(self):
        print("""All Staffs:
Number of staff:{self.x}
Staff ID:{self.x} Name:{self.name} Age: {self.age} Phone no:{self.num}""")
        pass
    def allGuest(self):
        pass
       
h = Hotel("Lakeshore") 
h.addStuff( "Adam", 26) 
print("=================================") 
print(h.getStuffById(1)) 
print("=================================") 
h.addGuest("Carol",35,"123") 
print("=================================") 
print(h.getGuestById(1)) 
print("=================================") 
h.addGuest("Diana", 32, "431") 
print("=================================") 
print(h.getGuestById(2)) 
print("=================================") 
h.allStaffs() 
print("=================================") 
h.allGuest()
# Out:
# Staff with ID 1 is added
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# ...
# Guestt with id 1 is created
# ...
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# ...
# Guestt with id 1 is created
# ...
# Guest ID: 2
# Name: Diana
# Age: 32
# Phone no.: 431
# ...
# All Staffs:
# Number of staff:{self.x}
# Staff ID:{self.x} Name:{self.name} Age: {self.age} Phone no:{self.num}
# ...

# %%
#22 araf #! p
class Hotel:
    def __init__(self, hotel):
        self.hotel = hotel
        self.staffs = dict()
        self.guests = dict()

    def addStuff(self, name, age, phone="000"):
        id = self.staffs.get(name, 0)+1
        self.staffs[id] = [name, age, phone]
        print(f"Staff with ID {id} is added")

    def addGuest(self, name, age, phone=000):
        id = len(self.guests)+1
        self.guests[id] = [name, age, phone]
        print(f"Guest with ID {id} is created")

    def getStuffById(self, id):
        return(f"""Staff ID: {id}
Name:{self.staffs[id][0]}
Age: {self.staffs[id][1]}
Phone no.: {self.staffs[id][2]}""")

    def getGuestById(self, id):
        return(f"""Guest ID: {id}
Name:{self.guests[id][0]}
Age: {self.guests[id][1]}
Phone no.: {self.guests[id][2]}""")

    def allStaffs(self):
        print(f"""All Staffs:
Number of staff: {len(self.staffs)}""")
        for k, v in self.staffs.items():
            print(f"Guest ID: {k} Name: {v[0]} Age: {v[1]} Phone no: {v[2]}")

    def allGuest(self):
        print(f"""All Guests:
Number of guest: {len(self.staffs)}""")
        for k, v in self.guests.items():
            print(f"Guest ID: {k} Name: {v[0]} Age: {v[1]} Phone no: {v[2]}")


# Do not change the following lines of code.
h = Hotel("Lakeshore")
h.addStuff("Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol", 35, "123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff with ID 1 is added
# ...
# Staff ID: 1
# Name:Adam
# Age: 26
# Phone no.: 000
# ...
# Guest with ID 1 is created
# ...
# Guest ID: 1
# Name:Carol
# Age: 35
# Phone no.: 123
# ...
# Guest with ID 2 is created
# ...
# Guest ID: 2
# Name:Diana
# Age: 32
# Phone no.: 431
# ...
# All Staffs:
# Number of staff: 1
# Guest ID: 1 Name: Adam Age: 26 Phone no: 000
# ...
# All Guests:
# Number of guest: 1
# Guest ID: 1 Name: Carol Age: 35 Phone no: 123
# Guest ID: 2 Name: Diana Age: 32 Phone no: 431

# %%
#23
class Author:
    def __init__(self):
        pass
    def addBook(self):
        pass
    def setName(self):
        pass
    def printDetail(self):
        pass
a1 = Author() 
print("=================================") 
a1.addBook("Ice", "Science Fiction") 
print("=================================") 
a1.setName("Anna Kavan") 
a1.addBook("Ice", "Science Fiction") 
a1.printDetail() 
print("=================================") 
a2 = Author("Humayun Ahmed") 
a2.addBook("Onnobhubon", "Science Fiction") 
a2.addBook("Megher Upor Bari", "Horror") 
print("=================================") 
a2.printDetail() 
a2.addBook("Ireena", "Science Fiction") 
print("=================================") 
a2.printDetail() 
print("=================================")

""""
================================= 
A book can not be added without author name 
================================= 
Number of Book(s): 1 
Author Name: Anna Kavan 
Science Fiction: Ice 
================================= 
================================= 
Number of Book(s): 2 
Author Name: Humayun Ahmed 
Science Fiction: Onnobhubon 
Horror: Megher Upor Bari 
================================= 
Number of Book(s): 3 
Author Name: Humayun Ahmed 
Science Fiction: Onnobhubon, Ireena 
Horror: Megher Upor Bari 
================================="""

# %%
#23 araf
class Author:
    def __init__(self, name=None):
        self.author = name
        self.books = dict()
        self.count = 0

    def addBook(self, book, genre):
        self.count += 1
        if self.author == None:
            print("A book can not be added without author name")
        else:
            if genre not in self.books:
                self.books[genre] = [book]
            else:
                self.books[genre].append(book)

    def setName(self, name):
        self.author = name

    def printDetail(self):
        print(f"""Number of Book(s): {self.count}
Author Name: {self.author}""")
        for k, v in self.books.items():
            print(f"{k} : {', '.join(v)}")


# Do not change the following lines of code.
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 2
# Author Name: Anna Kavan
# Science Fiction : Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon
# Horror : Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon, Ireena
# Horror : Megher Upor Bari
# ...
